# %% [markdown]
# <a href="https://colab.research.google.com/github/RareEminence/Projects/blob/master/simplelinearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
data = pd.read_csv('Linear_Regression.csv')

# %%
data.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
data.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
plt.scatter(data["x"],data["y"])
plt.xlabel("x")
plt.ylabel("y")
plt.title("Relationship B/W x and y")
plt.show()

# %%
X = data.iloc[:,0:1]
y = data.iloc[:,1:2]
X.head()
# Out:
#     x
# 0  77
# 1  21
# 2  22
# 3  20
# 4  36

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.7, test_size=0.3,random_state = 10)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.984972859019725

# %%
plt.scatter(data["x"],data["y"])
plt.plot(X_test,model.predict(X_test), color="red")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Regression Line")
plt.show()
